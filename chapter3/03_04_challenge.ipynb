# %%
import math
import collections
import itertools

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
words = {word.strip().lower() for word in open('words.txt', 'r')}

# %%
words
# Out:
# {'frette',
#  'shoddyward',
#  'unestimated',
#  'marianolatrist',
#  'prostatitic',
#  'refind',
#  'predamage',
#  'escalloniaceae',
#  'pancratium',
#  'anomodont',
#  'labefy',
#  'strepsipteral',
#  'unimbowed',
#  'lyrately',
#  'telemanometer',
#  'cholestane',
#  'shatter',
#  'disquisitorial',
#  'episiorrhaphy',
#  'unazotized',
#  'potwort',
#  'razzly',
#  'determinability',
#  'appliedly',
#  'terebic',
#  'conjobble',
#  'amphorophony',
#  'unseismic',
#  'sweamish',
#  'undeclaimed',
#  'guldengroschen',
#  'probankruptcy',
#  'preprohibition',
#  'coxarthropathy',
#  'powerfully',
#  'gnomically',
#  'witticism',
#  'yodelist',
#  'trisporic',
#  'phlegmatist',
#  'bemist',
#  'genuclast',
#  'ochraceous',
#  'globulet',
#  'lavable',
#  'allegement',
#  'uncopyrighted',
#  'microcolorimetric',
#  'glyoxim',
#  'healable',
#  'shekel',
#  'outtrick',
#  'splanchnographer',
#  'tetradite',
#  'almique',
#  'inlaut',
#  'portraitist',
#  'posteternity',
# ...

# %%
''.join(reversed('tearcat'))
# Out:
# 'tacraet'

# %%
# palindromes = {word: ''.join(reversed(word)) for word in words if ''.join(reversed(word)) in words}
palindromes = {tuple(sorted([word, word[::-1]])) for word in words if len(word) > 1 and word[::-1] in words}

# %%
palindromes
# Out:
# {('aa', 'aa'),
#  ('ab', 'ba'),
#  ('aba', 'aba'),
#  ('abac', 'caba'),
#  ('abas', 'saba'),
#  ('abba', 'abba'),
#  ('absi', 'isba'),
#  ('abut', 'tuba'),
#  ('acara', 'araca'),
#  ('acca', 'acca'),
#  ('acrid', 'dirca'),
#  ('ad', 'da'),
#  ('ada', 'ada'),
#  ('adad', 'dada'),
#  ('adar', 'rada'),
#  ('adda', 'adda'),
#  ('adet', 'teda'),
#  ('adinida', 'adinida'),
#  ('adman', 'namda'),
#  ('ado', 'oda'),
#  ('ae', 'ea'),
#  ('aer', 'rea'),
#  ('aes', 'sea'),
#  ('affa', 'affa'),
#  ('aga', 'aga'),
#  ('agama', 'amaga'),
#  ('agar', 'raga'),
#  ('agger', 'regga'),
#  ('agib', 'biga'),
#  ('agla', 'alga'),
#  ('agrom', 'morga'),
#  ('agust', 'tsuga'),
#  ('ah', 'ha'),
#  ('aha', 'aha'),
#  ('ahom', 'moha'),
#  ('aht', 'tha'),
#  ('aider', 'redia'),
#  ('aile', 'elia'),
#  ('air', 'ria'),
#  ('aira', 'aria'),
#  ('aire', 'eria'),
#  ('ajaja', 'ajaja'),
#  ('ajar', 'raja'),
#  ('ak', 'ka'),
#  ('aka', 'aka'),
#  ('akka', 'akka'),
#  ('ako', 'oka'),
#  ('al', 'la'),
# ...

# %%
'reflow'[::-1]
# Out:
# 'wolfer'

# %%
len(palindromes)
# Out:
# 712
